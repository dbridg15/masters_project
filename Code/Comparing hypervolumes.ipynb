# %% [markdown]
# # TO DO!
#
# - figure out how to deal with the fact that data is not great!

# %%
require(ggplot2)
source("00_functions_1.R")
# Out:
#  loading required packages

# %% [markdown]
# ## read in data

# %%
trees_df   = read.csv("../Results/trees_genus_matrix.csv", row.names=1)
mammals_df = read.csv("../Results/mammals_matrix.csv", row.names=1)
beetles_df = read.csv("../Results/beetles_matrix.csv", row.names=1)

# %%
pca.rslt_trees   = do_pca(trees_df, scale = F, plot = F)
pca.rslt_mammals = do_pca(mammals_df, scale = F, plot = F)
pca.rslt_beetles = do_pca(beetles_df, scale = F, plot = F)

# cat("Explained Varience Trees:")
# pca.rslt_trees@exp.var
# cat("Explained Varience Mammals:")
# pca.rslt_mammals@exp.var
# cat("Explained Varience Beetles:")
# pca.rslt_beetles@exp.var

# %%
hvs_rslts_trees   = hvs_rslts(pca.rslt_trees@axis, axis = c("PC1", "PC2", "PC3"))
hvs_rslts_mammals = hvs_rslts(pca.rslt_mammals@axis, axis = c("PC1", "PC2", "PC3"))
hvs_rslts_beetles = hvs_rslts(pca.rslt_beetles@axis, axis = c("PC1", "PC2", "PC3"))

# cat("\n\n")
# cat("Trees: ",   sum(is.na(hvs.rslts_trees@rslts$centroid_PC1))/nrow(hvs.rslts_trees@rslts), "\n")
# cat("Mammals: ", sum(is.na(hvs.rslts_mammals@rslts$centroid_PC1))/nrow(hvs.rslts_mammals@rslts), "\n")
# cat("Beetles: ", sum(is.na(hvs.rslts_beetles@rslts$centroid_PC1))/nrow(hvs.rslts_beetles@rslts))
# Out:
# Building Hypervolume  36  of  36 :  Tower_c44
# Comparing Hypervolume  54  of  54 :  Tower_c3-c44
#
# Building Hypervolume  36  of  36 :  E100-2_c2017
# Comparing Hypervolume  90  of  90 :  E100-2_c2016-c2017
#
# Building Hypervolume  60  of  60 :  VJR_P3
# Comparing Hypervolume  60  of  60 :  VJR_P2-P3

# %%
plts = unique(hvs_rslts_beetles@compare$plot)
for (i in plts){
  plot_hvs(hvs_rslts_beetles, i)
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
hvs_rslts_beetles@compare
# Out:
#           plot census_step centroid_change overlap     unique_1   unique_2
# A_P1-P2   A    P1-P2       0.42260867      0.060410741 0.93809909 0.284946237
# A_P1-P3   A    P1-P3       0.52202781      0.090535568 0.08445214 0.908701984
# A_P2-P3   A    P2-P3       0.66095258      0.007714541 0.10552764 0.992278431
# B_P1-P2   B    P1-P2               NA               NA         NA          NA
# B_P1-P3   B    P1-P3               NA               NA         NA          NA
# B_P2-P3   B    P2-P3       0.87523097      0.148116525 0.37030150 0.837751352
# C_P1-P2   C    P1-P2       1.73411909      0.044435431 0.95542842 0.064323111
# C_P1-P3   C    P1-P3       1.10594769      0.313424932 0.64094892 0.288477831
# C_P2-P3   C    P2-P3       0.97400086      0.091488854 0.02823795 0.908267272
# D_P1-P2   D    P1-P2       1.26269400      0.064382961 0.93517146 0.096456693
# D_P1-P3   D    P1-P3       2.01327132      0.026922749 0.97306014 0.023047375
# D_P2-P3   D    P2-P3       0.92656176      0.238813407 0.73313445 0.305634807
# E_P1-P2   E    P1-P2       3.22415623      0.010511783 0.98948701 0.010791367
# E_P1-P3   E    P1-P3       3.15235946      0.039544875 0.96040988 0.028089888
# E_P2-P3   E    P2-P3       0.45672970      0.218346091 0.13387902 0.774027229
# F_P1-P2   F    P1-P2       0.79936323      0.085057618 0.91480884 0.018096272
# F_P1-P3   F    P1-P3       0.83301711      0.460089859 0.45492383 0.253108463
# F_P2-P3   F    P2-P3       0.81522268      0.109095394 0.07424329 0.889941687
# LF1_P1-P2 LF1  P1-P2       0.20458367      0.394433105 0.59812882 0.044821370
# LF1_P1-P3 LF1  P1-P3       1.24857093      0.097800905 0.90188881 0.031324481
# LF1_P2-P3 LF1  P2-P3       1.04398798      0.196569606 0.79617512 0.153320164
# LF2_P1-P2 LF2  P1-P2       1.47945476      0.035999345 0.02211055 0.963971329
# LF2_P1-P3 LF2  P1-P3       0.55813307      0.178243371 0.03628954 0.820552186
# LF2_P2-P3 LF2  P2-P3       0.92132337      0.189677183 0.80901754 0.034779357
# LF3_P1-P2 LF3  P1-P2       0.36355374      0.309306628 0.03661844 0.687013640
# LF3_P1-P3 LF3  P1-P3       0.52141711      0.340816569 0.04232646 0.653971154
# LF3_P2-P3 LF3  P2-P3       0.15786453      0.671728076 0.23688992 0.151298595
# LFE_P1-P2 LFE  P1-P2       1.37910782      0.007525354 0.99246648 0.125954198
# LFE_P1-P3 LFE  P1-P3       0.58236960      0.283389102 0.71272623 0.045543906
# LFE_P2-P3 LFE  P2-P3       0.92664300      0.024287377 0.14827995 0.975609492
# LF_P1-P2  LF   P1-P2       0.86776673      0.265618630 0.69751329 0.314535971
# LF_P1-P3  LF   P1-P3       1.29985015      0.029638498 0.97031384 0.051388889
# LF_P2-P3  LF   P2-P3       0.64825459      0.064187303 0.93540685 0.089159718
# OG1_P1-P2 OG1  P1-P2       1.88502980      0.148660187 0.84945462 0.077690972
# OG1_P1-P3 OG1  P1-P3       1.64178371      0.100163673 0.89943896 0.037953236
# OG1_P2-P3 OG1  P2-P3       0.24324626      0.370246669 0.55676019 0.307856476
# OG2_P1-P2 OG2  P1-P2       1.71787326      0.010369621 0.98962845 0.017595308
# OG2_P1-P3 OG2  P1-P3       1.38230353      0.032991852 0.96698465 0.021120294
# OG2_P2-P3 OG2  P2-P3       0.33556974      0.298170733 0.03653327 0.698419537
# OG3_P1-P2 OG3  P1-P2       0.05487075      0.420393280 0.08938259 0.561512930
# OG3_P1-P3 OG3  P1-P3       0.04162593      0.498497787 0.07637071 0.480071531
# OG3_P2-P3 OG3  P2-P3       0.09649580      0.696888929 0.23800815 0.109209889
# OG_P1-P2  OG   P1-P2       0.93095496      0.177211248 0.81848435 0.118022657
# OG_P1-P3  OG   P1-P3       0.91649125      0.256572345 0.70211938 0.350854503
# OG_P2-P3  OG   P2-P3       1.75941408      0.216602877 0.42498977 0.742111472
# OP1_P1-P2 OP1  P1-P2               NA               NA         NA          NA
# OP1_P1-P3 OP1  P1-P3               NA               NA         NA          NA
# OP1_P2-P3 OP1  P2-P3       0.06337858      0.091681901 0.02275641 0.908121946
# OP2_P1-P2 OP2  P1-P2               NA               NA         NA          NA
# OP2_P1-P3 OP2  P1-P3               NA               NA         NA          NA
# OP2_P2-P3 OP2  P2-P3       0.30139248      0.092595647 0.02961358 0.907141958
# OP3_P1-P2 OP3  P1-P2       0.41836697      0.004744604 0.99525452 0.037267081
# OP3_P1-P3 OP3  P1-P3       0.21712089      0.394323119 0.05120000 0.597103724
# OP3_P2-P3 OP3  P2-P3       0.63548770      0.002093112 0.00000000 0.997906888
# OP_P1-P2  OP   P1-P2       1.82761290      0.008286444 0.99171301 0.007905138
# OP_P1-P3  OP   P1-P3       3.54396433      0.279294475 0.45957730 0.633705933
# OP_P2-P3  OP   P2-P3       3.76842119      0.005357461 0.05343511 0.994640918
# VJR_P1-P2 VJR  P1-P2               NA               NA         NA          NA
# VJR_P1-P3 VJR  P1-P3               NA               NA         NA          NA
# VJR_P2-P3 VJR  P2-P3       0.93793256      0.108212431 0.21317939 0.888519079
#           abs_vol_change per_vol_change
# A_P1-P2   -3.653709e-01   -0.9134318
# A_P1-P3    3.611232e+00    9.0281244
# A_P2-P3    3.976603e+00  114.8407543
# B_P1-P2              NA           NA
# B_P1-P3              NA           NA
# B_P2-P3    7.338712e+00    2.8810709
# C_P1-P2   -4.944516e+01   -0.9523643
# C_P1-P3   -2.571910e+01   -0.4953761
# C_P2-P3    2.372606e+01    9.5934062
# D_P1-P2   -1.465699e+02   -0.9282508
# D_P1-P3   -1.535449e+02   -0.9724246
# D_P2-P3   -6.975006e+00   -0.6156697
# E_P1-P2   -1.578621e+02   -0.9893723
# E_P1-P3   -1.530583e+02   -0.9592657
# E_P2-P3    4.803755e+00    2.8328555
# F_P1-P2   -3.326934e+01   -0.9132388
# F_P1-P3   -9.843657e+00   -0.2702071
# F_P2-P3    2.342568e+01    7.4115110
# LF1_P1-P2 -2.180377e-02   -0.5792712
# LF1_P1-P3 -3.382768e-02   -0.8987161
# LF1_P2-P3 -1.202391e-02   -0.7592657
# LF2_P1-P2  4.752063e-02   26.1419791
# LF2_P1-P3  7.944510e-03    4.3704218
# LF2_P2-P3 -3.957612e-02   -0.8021360
# LF3_P1-P2  4.852851e-03    2.0780305
# LF3_P1-P3  4.127926e-03    1.7676119
# LF3_P2-P3 -7.249245e-04   -0.1008498
# LFE_P1-P2 -3.779546e+01   -0.9913809
# LFE_P1-P3 -2.664942e+01   -0.6990184
# LFE_P2-P3  1.114605e+01   33.9201442
# LF_P1-P2  -9.719556e+00   -0.5587125
# LF_P1-P3  -1.685194e+01   -0.9687057
# LF_P2-P3  -7.132382e+00   -0.9290840
# OG1_P1-P2 -3.076147e-02   -0.8367734
# OG1_P1-P3 -3.291934e-02   -0.8954718
# OG1_P2-P3 -2.157871e-03   -0.3596129
# OG2_P1-P2 -9.078639e-02   -0.9894427
# OG2_P1-P3 -8.866039e-02   -0.9662723
# OG2_P2-P3  2.126001e-03    2.1947253
# OG3_P1-P2  5.965027e-04    1.0767258
# OG3_P1-P3  4.301534e-04    0.7764545
# OG3_P2-P3 -1.663493e-04   -0.1445888
# OG_P1-P2  -1.112875e+01   -0.7941947
# OG_P1-P3  -7.582496e+00   -0.5411189
# OG_P2-P3   3.546256e+00    1.2296852
# OP1_P1-P2            NA           NA
# OP1_P1-P3            NA           NA
# OP1_P2-P3  1.560849e-05    9.6363113
# OP2_P1-P2            NA           NA
# OP2_P1-P3            NA           NA
# OP2_P2-P3  4.119440e-04    9.4502141
# OP3_P1-P2 -1.219126e-03   -0.9950708
# OP3_P1-P3  1.660036e-03    1.3549485
# OP3_P2-P3  2.879162e-03  476.7574473
# OP_P1-P2  -1.414091e+01   -0.9916470
# OP_P1-P3   6.778923e+00    0.4753793
# OP_P2-P3   2.091984e+01  175.6281917
# VJR_P1-P2            NA           NA
# VJR_P1-P3            NA           NA
# VJR_P2-P3  1.893332e+01    6.0578948

# %% [markdown]
# ## model???!!!

# %%
attributes <- read.csv("../Results/trees_sorted.csv")
a = as.data.frame(attributes %>% group_by(plot_c) %>% summarise(stem_C = sum(stem_C)))

hvs_rslts_trees@rslts   = merge(hvs_rslts_trees@rslts, a, by = "plot_c", all.x = T)
# need to figure out compare - maybe do change in AGB too?
# hvs_rslts_trees@compare = merge(hvs_rslts_trees@compare, a, by = "plot_c", all.x = T)

# %%
df = hvs_rslts_trees@rslts
mdl = lm(centroid_PC1 ~ stem_C*census, data = df)
summary(mdl)
# Out:
# Call:
# lm(formula = centroid_PC1 ~ stem_C * census, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6491 -0.4118 -0.2043  0.3716  1.0612
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      7.470e-01  3.510e-01   2.128   0.0448 *
# stem_C          -6.294e-06  2.461e-06  -2.557   0.0180 *
# censusc2         1.629e-01  5.021e-01   0.324   0.7486
# censusc3         1.038e-01  5.093e-01   0.204   0.8404
# censusc4        -7.363e-02  7.741e-01  -0.095   0.9251
# stem_C:censusc2 -5.317e-07  3.446e-06  -0.154   0.8788
# stem_C:censusc3  5.643e-07  3.576e-06   0.158   0.8761
# stem_C:censusc4  4.337e-07  1.117e-05   0.039   0.9694
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6087 on 22 degrees of freedom
#   (6 observations deleted due to missingness)
# Multiple R-squared:  0.486,	Adjusted R-squared:  0.3225
# F-statistic: 2.972 on 7 and 22 DF,  p-value: 0.02366

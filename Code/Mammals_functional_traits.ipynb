# %%
df <- read.csv("../Results/mammals_sorted.csv")

# %%
apply(df, 2, function(x) sum(!is.na(x)))
# Out:
#                      Occasion                          Date
#                          3703                          3703
#                       Trap_ID                     Species_x
#                          3703                          3703
#                    New.Return                        Tag_no
#                          3703                          3703
#                           Age                           Sex
#                          3703                          3703
#                  Sexing_Notes                            HF
#                          3703                          1708
#                             E                           AGD
#                          3703                          1404
#                            HB                             T
#                          3703                          3703
#                       Tail.HB                            MZ
#                          3703                          3703
# ...
